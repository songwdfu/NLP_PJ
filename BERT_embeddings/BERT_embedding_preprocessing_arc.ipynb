# %%
import torch
import pickle as pkl
import pandas as pd
import numpy as np

# %%
import os
os.chdir('..')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from sentence_transformers import SentenceTransformer

model_name = 'bert-base-nli-mean-tokens'
model = SentenceTransformer(model_name)

# %%
device = torch.device('cuda:0')

# %%
model.to(device)
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# )

# %%
arc_body = pd.read_csv('/gpt_embeddings/pure_arc_body.csv')

# %%
arc_body
# Out:
#       Body ID                                        articleBody
# 0       90000  I'm curious when Democrats pull the lever for ...
# 1       90001  This is the worst article this newspaper has e...
# 2       90002  'No spic Inglés, señor.' -Escúchame: No temas,...
# 3       90003  Not a good idea because it would set a precede...
# 4       90004  I find it laughable that all the liberals argu...
# ...       ...                                                ...
# 4443    94443  My girls' friend was texting through a movie, ...
# 4444    94444  If home captivity is the issue, then how to ex...
# 4445    94445  It is easier for us at home and at our lake ca...
# 4446    94446  Wonderful essay, thanks. The villain isn't ele...
# 4447    94447  Growing up in a joint custody family my weeken...
#
# [4448 rows x 2 columns]

# %%
arc_head = pd.read_csv('/gpt_embeddings/pure_arc_stance.csv')

# %%
arc_head
# Out:
#                                             Headline  Body ID     Stance
# 0      We don't need to hear from candidate's spouse    90628      agree
# 1                       Comment sections have failed    91932  unrelated
# 2               Casinos are not too much of a gamble    92724  unrelated
# 3              New York's bike lanes are not working    93804  unrelated
# 4                       Drone attacks make more harm    91445  unrelated
# ...                                              ...      ...        ...
# 14228             3-D printing will change the world    90050  unrelated
# 14229              Mother Teresa should be canonized    91820  unrelated
# 14230                   Comment sections have failed    93169  unrelated
# 14231       Colleges do not need humanities programs    93466  unrelated
# 14232         Extreme parenting is counterproductive    90418  unrelated
#
# [14233 rows x 3 columns]

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
arc_head['sentences'] = arc_head['Headline'].apply(sent_tokenize)
arc_body['sentences'] = arc_body['articleBody'].apply(sent_tokenize)

# %%
def get_embedding(sent):
    return model.encode(sent)

# %%
arc_body['embeddings'] = arc_body['sentences'].apply(get_embedding)

# %%
arc_head['embeddings'] = arc_head['sentences'].apply(get_embedding)

# %%
arc_train = arc_head.merge(arc_body, on='Body ID', suffixes=['_head', '_body'])

# %%
arc_train['embeddings_body'] = arc_train['embeddings_body'].apply(torch.tensor)
arc_train['embeddings_head'] = arc_train['embeddings_head'].apply(torch.tensor)

# %%
label_mapping = {'unrelated': 0, 'agree': 1, 'discuss': 2, 'disagree': 3}

arc_train['Stance'] = arc_train['Stance'].map(label_mapping)

# %%
arc_train
# Out:
#                                                 Headline  Body ID  Stance  \
# 0          We don't need to hear from candidate's spouse    90628       1
# 1           Guns should be permitted on college campuses    90628       0
# 2      Young people are being irresponsible by delayi...    90628       0
# 3           Guns should be permitted on college campuses    90628       0
# 4                California doesn't need high-speed rail    90628       0
# ...                                                  ...      ...     ...
# 14228                  Greece will destroy the Euro Zone    91602       0
# 14229               Prostituion is safer when it's legal    90826       3
# 14230                                 Fees are necessary    92816       0
# 14231                            We don't need libraries    91291       3
# 14232                          People are getting dumber    91461       1
#
#                                           sentences_head  \
# 0        [We don't need to hear from candidate's spouse]
# 1         [Guns should be permitted on college campuses]
# 2      [Young people are being irresponsible by delay...
# 3         [Guns should be permitted on college campuses]
# 4              [California doesn't need high-speed rail]
# ...                                                  ...
# 14228                [Greece will destroy the Euro Zone]
# 14229             [Prostituion is safer when it's legal]
# 14230                               [Fees are necessary]
# 14231                          [We don't need libraries]
# 14232                        [People are getting dumber]
#
#                                          embeddings_head  \
# 0      [[tensor(0.7675), tensor(0.9844), tensor(2.252...
# 1      [[tensor(0.5609), tensor(0.5146), tensor(0.873...
# 2      [[tensor(0.5083), tensor(0.3331), tensor(1.156...
# 3      [[tensor(0.5609), tensor(0.5146), tensor(0.873...
# 4      [[tensor(0.9430), tensor(0.2814), tensor(0.311...
# ...                                                  ...
# 14228  [[tensor(-0.2398), tensor(0.3448), tensor(0.36...
# 14229  [[tensor(-0.4055), tensor(-0.5117), tensor(0.7...
# 14230  [[tensor(-0.1438), tensor(-0.5031), tensor(1.9...
# 14231  [[tensor(0.9495), tensor(0.7203), tensor(1.357...
# 14232  [[tensor(0.4785), tensor(0.0263), tensor(1.440...
#
#                                              articleBody  \
# 0      Wives should never speak at conventions or on ...
# 1      Wives should never speak at conventions or on ...
# 2      Wives should never speak at conventions or on ...
# 3      Wives should never speak at conventions or on ...
# 4      Wives should never speak at conventions or on ...
# ...                                                  ...
# 14228  I disagree with coersion being the option. An ...
# 14229  Prostitution is harmful and dehumanizing and e...
# 14230  The fact Bush got elected twice and Perry seve...
# 14231  It will be a sad day for all of us when librar...
# 14232  In our society, people have to be told that th...
#
#                                           sentences_body  \
# 0      [Wives should never speak at conventions or on...
# 1      [Wives should never speak at conventions or on...
# 2      [Wives should never speak at conventions or on...
# 3      [Wives should never speak at conventions or on...
# 4      [Wives should never speak at conventions or on...
# ...                                                  ...
# 14228  [I disagree with coersion being the option., A...
# 14229  [Prostitution is harmful and dehumanizing and ...
# 14230  [The fact Bush got elected twice and Perry sev...
# 14231  [It will be a sad day for all of us when libra...
# 14232  [In our society, people have to be told that t...
#
#                                          embeddings_body
# 0      [[tensor(-0.0928), tensor(0.9080), tensor(1.39...
# 1      [[tensor(-0.0928), tensor(0.9080), tensor(1.39...
# 2      [[tensor(-0.0928), tensor(0.9080), tensor(1.39...
# 3      [[tensor(-0.0928), tensor(0.9080), tensor(1.39...
# 4      [[tensor(-0.0928), tensor(0.9080), tensor(1.39...
# ...                                                  ...
# 14228  [[tensor(0.7141), tensor(0.6541), tensor(1.680...
# 14229  [[tensor(-0.2160), tensor(0.0737), tensor(-0.1...
# 14230  [[tensor(-0.0203), tensor(0.3725), tensor(-0.2...
# 14231  [[tensor(-0.5685), tensor(0.5428), tensor(1.05...
# 14232  [[tensor(-0.3498), tensor(0.5426), tensor(0.35...
#
# [14233 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
fnc_train = pkl.load(open('/gpt_embeddings/fnc_train.pkl','rb'))

# %%
total_train = pd.concat([arc_train, fnc_train], axis=0)

# %%
total_train.Stance.unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %%
total_train, total_val = train_test_split(total_train, test_size=0.2, random_state=42)

# %%
pkl.dump(total_train, open('gpt_embeddings/total_train.pkl','wb'))
pkl.dump(total_val, open('gpt_embeddings/total_val.pkl', 'wb'))

# %%
total_train_copy = pkl.load(open('gpt_embeddings/total_train.pkl','rb'))
total_val_copy = pkl.load(open('gpt_embeddings/total_val.pkl', 'rb'))

# %%
total_train_copy
# Out:
#                                                 Headline  Body ID  Stance  \
# 38384  Isis leader Abu Bakr al-Baghdadi's 'wife and s...     1913       0
# 20073  Lady on FB: I'm 41, Intersex, and Fucked Micha...      879       0
# 8404   James Wright Foley, Kidnapped Journalist, Appa...      139       0
# 26909       Michael Brown shooting audio caught on tape?      195       0
# 7671                         Marijuana is a gateway drug    91046       0
# ...                                                  ...      ...     ...
# 48337    Seven teenage girls get pregnant on school trip     1804       1
# 23925  Macaulay Culkin Dead: Actor Once Again Victim ...      498       0
# 860                     Big banks are not out of control    92226       0
# 1562    Texas City plumber's truck ends up in Syrian war     2344       0
# 42189  Islamic State Militants Claim to Have Beheaded...     1747       2
#
#                                           sentences_head  \
# 38384  [Isis leader Abu Bakr al-Baghdadi's 'wife and ...
# 20073  [Lady on FB: I'm 41, Intersex, and Fucked Mich...
# 8404   [James Wright Foley, Kidnapped Journalist, App...
# 26909     [Michael Brown shooting audio caught on tape?]
# 7671                       [Marijuana is a gateway drug]
# ...                                                  ...
# 48337  [Seven teenage girls get pregnant on school trip]
# 23925  [Macaulay Culkin Dead: Actor Once Again Victim...
# 860                   [Big banks are not out of control]
# 1562   [Texas City plumber's truck ends up in Syrian ...
# 42189  [Islamic State Militants Claim to Have Beheade...
#
#                                          embeddings_head  \
# 38384  [[tensor(-0.2697), tensor(0.9552), tensor(-0.1...
# 20073  [[tensor(-0.4410), tensor(0.7908), tensor(0.08...
# 8404   [[tensor(0.3436), tensor(0.1727), tensor(-0.29...
# 26909  [[tensor(0.5646), tensor(0.4658), tensor(-0.23...
# 7671   [[tensor(-0.0491), tensor(0.0707), tensor(0.99...
# ...                                                  ...
# 48337  [[tensor(-0.4397), tensor(0.0199), tensor(-0.0...
# 23925  [[tensor(0.3356), tensor(0.4754), tensor(1.345...
# 860    [[tensor(0.4441), tensor(-0.8802), tensor(0.44...
# 1562   [[tensor(0.1310), tensor(0.5537), tensor(-0.24...
# 42189  [[tensor(0.4611), tensor(0.5028), tensor(-0.53...
#
#                                              articleBody  \
# 38384  A blast near the Nicaraguan capital city of Ma...
# 20073  Matt Taibbi is taking a “leave of absence” fro...
# 8404   Judd Nelson rebuffs Internet rumors that he di...
# 26909  A video posted by ISIL terrorists in Iraq purp...
# 7671   The whole world of nutrition is a mind field f...
# ...                                                  ...
# 48337  Seven girls from a Bosnian school, all aged be...
# 23925  Twitter users are suggesting the phallic daubi...
# 860    Thank you. I believe this is what is important...
# 1562   North Korea may have a woman at the helm–Kim J...
# 42189  A message from Jim's mom, Diane Foley:\r\nWe h...
#
#                                           sentences_body  \
# 38384  [A blast near the Nicaraguan capital city of M...
# 20073  [Matt Taibbi is taking a “leave of absence” fr...
# 8404   [Judd Nelson rebuffs Internet rumors that he d...
# 26909  [A video posted by ISIL terrorists in Iraq pur...
# 7671   [The whole world of nutrition is a mind field ...
# ...                                                  ...
# 48337  [Seven girls from a Bosnian school, all aged b...
# 23925  [Twitter users are suggesting the phallic daub...
# 860    [Thank you., I believe this is what is importa...
# 1562   [North Korea may have a woman at the helm–Kim ...
# 42189  [A message from Jim's mom, Diane Foley:\r\nWe ...
#
#                                          embeddings_body
# 38384  [[tensor(-0.0075), tensor(0.4806), tensor(-0.3...
# 20073  [[tensor(0.0762), tensor(-0.0156), tensor(1.25...
# 8404   [[tensor(0.3818), tensor(0.8142), tensor(0.356...
# 26909  [[tensor(0.4329), tensor(0.6699), tensor(-0.40...
# 7671   [[tensor(-0.1277), tensor(0.2603), tensor(0.08...
# ...                                                  ...
# 48337  [[tensor(-0.5624), tensor(0.6778), tensor(-0.4...
# 23925  [[tensor(-0.3486), tensor(1.1035), tensor(-0.6...
# 860    [[tensor(-0.0789), tensor(0.0615), tensor(2.75...
# 1562   [[tensor(0.1755), tensor(-0.2210), tensor(1.11...
# 42189  [[tensor(-0.2226), tensor(1.4339), tensor(1.21...
#
# [51364 rows x 8 columns]

# %%
total_val_copy
# Out:
#                                                 Headline  Body ID  Stance  \
# 47361              Nun gives birth, intends to keep baby      391       0
# 21733           Kim Jong-un So Fat He Injured His Ankles     1103       0
# 12631  Christian Bale in Talks to Play Steve Jobs in ...     2455       2
# 43533  That Was Fast: Christian Bale Bails on Steve J...     1841       1
# 48539  How Canadian Sergeant-at-Arms Kevin Vickers ki...     1472       2
# ...                                                  ...      ...     ...
# 3391                      Abolish Birthright Citizenship    90226       0
# 46992  SEND IN THE DRONES: Predator drones flown over...     2186       0
# 9014             It should be illegal to declaw your cat    91909       0
# 19858  New Audio Recording From Ferguson May Capture ...      693       2
# 11897  Tim Cook Reportedly Showers with Apple Watch, ...      908       0
#
#                                           sentences_head  \
# 47361            [Nun gives birth, intends to keep baby]
# 21733         [Kim Jong-un So Fat He Injured His Ankles]
# 12631  [Christian Bale in Talks to Play Steve Jobs in...
# 43533  [That Was Fast: Christian Bale Bails on Steve ...
# 48539  [How Canadian Sergeant-at-Arms Kevin Vickers k...
# ...                                                  ...
# 3391                    [Abolish Birthright Citizenship]
# 46992  [SEND IN THE DRONES: Predator drones flown ove...
# 9014           [It should be illegal to declaw your cat]
# 19858  [New Audio Recording From Ferguson May Capture...
# 11897  [Tim Cook Reportedly Showers with Apple Watch,...
#
#                                          embeddings_head  \
# 47361  [[tensor(0.9288), tensor(0.3911), tensor(1.291...
# 21733  [[tensor(0.0239), tensor(0.1279), tensor(-0.37...
# 12631  [[tensor(0.4828), tensor(0.2569), tensor(0.634...
# 43533  [[tensor(-0.0392), tensor(0.6430), tensor(0.68...
# 48539  [[tensor(0.5736), tensor(0.6943), tensor(-0.68...
# ...                                                  ...
# 3391   [[tensor(0.0406), tensor(0.5931), tensor(0.190...
# 46992  [[tensor(0.1675), tensor(0.5462), tensor(0.105...
# 9014   [[tensor(0.2775), tensor(0.3884), tensor(1.088...
# 19858  [[tensor(0.6904), tensor(-0.2299), tensor(1.37...
# 11897  [[tensor(-0.2034), tensor(1.6244), tensor(-0.4...
#
#                                              articleBody  \
# 47361  The Department of Homeland Security flatly den...
# 21733  When most parents think of a school trip, they...
# 12631  Cristian Bale is eyeing — or i-ing, if you pre...
# 43533  After early discussions to play the Apple foun...
# 48539  Kevin Vickers, sergeant-at-arms of the House o...
# ...                                                  ...
# 3391   Nope. I, a male, taught at an all girls high s...
# 46992  A hoax that went viral on the internet has lef...
# 9014   There is a great responsibility to parenting. ...
# 19858  (KTVI)- An audio recording that allegedly capt...
# 11897  ISIS supporters are circulating images of a ch...
#
#                                           sentences_body  \
# 47361  [The Department of Homeland Security flatly de...
# 21733  [When most parents think of a school trip, the...
# 12631  [Cristian Bale is eyeing — or i-ing, if you pr...
# 43533  [After early discussions to play the Apple fou...
# 48539  [Kevin Vickers, sergeant-at-arms of the House ...
# ...                                                  ...
# 3391   [Nope., I, a male, taught at an all girls high...
# 46992  [A hoax that went viral on the internet has le...
# 9014   [There is a great responsibility to parenting....
# 19858  [(KTVI)- An audio recording that allegedly cap...
# 11897  [ISIS supporters are circulating images of a c...
#
#                                          embeddings_body
# 47361  [[tensor(-0.2243), tensor(0.7804), tensor(-0.1...
# 21733  [[tensor(-0.5554), tensor(-0.5530), tensor(0.9...
# 12631  [[tensor(-0.2053), tensor(1.2861), tensor(-0.2...
# 43533  [[tensor(0.0424), tensor(0.4565), tensor(0.255...
# 48539  [[tensor(0.0711), tensor(0.3848), tensor(0.545...
# ...                                                  ...
# 3391   [[tensor(0.4658), tensor(0.2772), tensor(2.624...
# 46992  [[tensor(0.2566), tensor(0.3845), tensor(0.585...
# 9014   [[tensor(0.1783), tensor(-0.0731), tensor(1.25...
# 19858  [[tensor(0.3192), tensor(0.2311), tensor(-0.02...
# 11897  [[tensor(-0.0692), tensor(0.4170), tensor(-0.1...
#
# [12841 rows x 8 columns]

# %%
trans = lambda x: torch.mean(x, dim=0)

# %%
total_train_copy['embeddings_head'] = total_train_copy['embeddings_head'].apply(trans)
total_train_copy['embeddings_body'] = total_train_copy['embeddings_body'].apply(trans)
total_val_copy['embeddings_head'] = total_val_copy['embeddings_head'].apply(trans)
total_val_copy['embeddings_body'] = total_val_copy['embeddings_body'].apply(trans)

# %%
total_train_copy
# Out:
#                                                 Headline  Body ID  Stance  \
# 38384  Isis leader Abu Bakr al-Baghdadi's 'wife and s...     1913       0
# 20073  Lady on FB: I'm 41, Intersex, and Fucked Micha...      879       0
# 8404   James Wright Foley, Kidnapped Journalist, Appa...      139       0
# 26909       Michael Brown shooting audio caught on tape?      195       0
# 7671                         Marijuana is a gateway drug    91046       0
# ...                                                  ...      ...     ...
# 48337    Seven teenage girls get pregnant on school trip     1804       1
# 23925  Macaulay Culkin Dead: Actor Once Again Victim ...      498       0
# 860                     Big banks are not out of control    92226       0
# 1562    Texas City plumber's truck ends up in Syrian war     2344       0
# 42189  Islamic State Militants Claim to Have Beheaded...     1747       2
#
#                                           sentences_head  \
# 38384  [Isis leader Abu Bakr al-Baghdadi's 'wife and ...
# 20073  [Lady on FB: I'm 41, Intersex, and Fucked Mich...
# 8404   [James Wright Foley, Kidnapped Journalist, App...
# 26909     [Michael Brown shooting audio caught on tape?]
# 7671                       [Marijuana is a gateway drug]
# ...                                                  ...
# 48337  [Seven teenage girls get pregnant on school trip]
# 23925  [Macaulay Culkin Dead: Actor Once Again Victim...
# 860                   [Big banks are not out of control]
# 1562   [Texas City plumber's truck ends up in Syrian ...
# 42189  [Islamic State Militants Claim to Have Beheade...
#
#                                          embeddings_head  \
# 38384  [tensor(-0.2697), tensor(0.9552), tensor(-0.13...
# 20073  [tensor(-0.4410), tensor(0.7908), tensor(0.085...
# 8404   [tensor(0.3436), tensor(0.1727), tensor(-0.294...
# 26909  [tensor(0.5646), tensor(0.4658), tensor(-0.232...
# 7671   [tensor(-0.0491), tensor(0.0707), tensor(0.991...
# ...                                                  ...
# 48337  [tensor(-0.4397), tensor(0.0199), tensor(-0.05...
# 23925  [tensor(0.3356), tensor(0.4754), tensor(1.3451...
# 860    [tensor(0.4441), tensor(-0.8802), tensor(0.442...
# 1562   [tensor(0.1310), tensor(0.5537), tensor(-0.243...
# 42189  [tensor(0.4611), tensor(0.5028), tensor(-0.532...
#
#                                              articleBody  \
# 38384  A blast near the Nicaraguan capital city of Ma...
# 20073  Matt Taibbi is taking a “leave of absence” fro...
# 8404   Judd Nelson rebuffs Internet rumors that he di...
# 26909  A video posted by ISIL terrorists in Iraq purp...
# 7671   The whole world of nutrition is a mind field f...
# ...                                                  ...
# 48337  Seven girls from a Bosnian school, all aged be...
# 23925  Twitter users are suggesting the phallic daubi...
# 860    Thank you. I believe this is what is important...
# 1562   North Korea may have a woman at the helm–Kim J...
# 42189  A message from Jim's mom, Diane Foley:\r\nWe h...
#
#                                           sentences_body  \
# 38384  [A blast near the Nicaraguan capital city of M...
# 20073  [Matt Taibbi is taking a “leave of absence” fr...
# 8404   [Judd Nelson rebuffs Internet rumors that he d...
# 26909  [A video posted by ISIL terrorists in Iraq pur...
# 7671   [The whole world of nutrition is a mind field ...
# ...                                                  ...
# 48337  [Seven girls from a Bosnian school, all aged b...
# 23925  [Twitter users are suggesting the phallic daub...
# 860    [Thank you., I believe this is what is importa...
# 1562   [North Korea may have a woman at the helm–Kim ...
# 42189  [A message from Jim's mom, Diane Foley:\r\nWe ...
#
#                                          embeddings_body
# 38384  [tensor(0.1567), tensor(0.4139), tensor(0.0904...
# 20073  [tensor(0.0924), tensor(0.3163), tensor(1.1158...
# 8404   [tensor(0.1822), tensor(0.5470), tensor(0.3063...
# 26909  [tensor(0.3007), tensor(0.2842), tensor(0.4186...
# 7671   [tensor(0.1469), tensor(0.5588), tensor(-0.003...
# ...                                                  ...
# 48337  [tensor(-0.1658), tensor(0.4432), tensor(0.524...
# 23925  [tensor(0.0507), tensor(0.6100), tensor(-0.099...
# 860    [tensor(-0.2332), tensor(0.2352), tensor(1.288...
# 1562   [tensor(-0.2684), tensor(0.2057), tensor(0.678...
# 42189  [tensor(-0.0592), tensor(1.0054), tensor(0.889...
#
# [51364 rows x 8 columns]

# %%
total_val_copy
# Out:
#                                                 Headline  Body ID  Stance  \
# 47361              Nun gives birth, intends to keep baby      391       0
# 21733           Kim Jong-un So Fat He Injured His Ankles     1103       0
# 12631  Christian Bale in Talks to Play Steve Jobs in ...     2455       2
# 43533  That Was Fast: Christian Bale Bails on Steve J...     1841       1
# 48539  How Canadian Sergeant-at-Arms Kevin Vickers ki...     1472       2
# ...                                                  ...      ...     ...
# 3391                      Abolish Birthright Citizenship    90226       0
# 46992  SEND IN THE DRONES: Predator drones flown over...     2186       0
# 9014             It should be illegal to declaw your cat    91909       0
# 19858  New Audio Recording From Ferguson May Capture ...      693       2
# 11897  Tim Cook Reportedly Showers with Apple Watch, ...      908       0
#
#                                           sentences_head  \
# 47361            [Nun gives birth, intends to keep baby]
# 21733         [Kim Jong-un So Fat He Injured His Ankles]
# 12631  [Christian Bale in Talks to Play Steve Jobs in...
# 43533  [That Was Fast: Christian Bale Bails on Steve ...
# 48539  [How Canadian Sergeant-at-Arms Kevin Vickers k...
# ...                                                  ...
# 3391                    [Abolish Birthright Citizenship]
# 46992  [SEND IN THE DRONES: Predator drones flown ove...
# 9014           [It should be illegal to declaw your cat]
# 19858  [New Audio Recording From Ferguson May Capture...
# 11897  [Tim Cook Reportedly Showers with Apple Watch,...
#
#                                          embeddings_head  \
# 47361  [tensor(0.9288), tensor(0.3911), tensor(1.2913...
# 21733  [tensor(0.0239), tensor(0.1279), tensor(-0.377...
# 12631  [tensor(0.4828), tensor(0.2569), tensor(0.6341...
# 43533  [tensor(-0.0392), tensor(0.6430), tensor(0.682...
# 48539  [tensor(0.5736), tensor(0.6943), tensor(-0.687...
# ...                                                  ...
# 3391   [tensor(0.0406), tensor(0.5931), tensor(0.1904...
# 46992  [tensor(0.1675), tensor(0.5462), tensor(0.1052...
# 9014   [tensor(0.2775), tensor(0.3884), tensor(1.0888...
# 19858  [tensor(0.6904), tensor(-0.2299), tensor(1.373...
# 11897  [tensor(-0.2034), tensor(1.6244), tensor(-0.42...
#
#                                              articleBody  \
# 47361  The Department of Homeland Security flatly den...
# 21733  When most parents think of a school trip, they...
# 12631  Cristian Bale is eyeing — or i-ing, if you pre...
# 43533  After early discussions to play the Apple foun...
# 48539  Kevin Vickers, sergeant-at-arms of the House o...
# ...                                                  ...
# 3391   Nope. I, a male, taught at an all girls high s...
# 46992  A hoax that went viral on the internet has lef...
# 9014   There is a great responsibility to parenting. ...
# 19858  (KTVI)- An audio recording that allegedly capt...
# 11897  ISIS supporters are circulating images of a ch...
#
#                                           sentences_body  \
# 47361  [The Department of Homeland Security flatly de...
# 21733  [When most parents think of a school trip, the...
# 12631  [Cristian Bale is eyeing — or i-ing, if you pr...
# 43533  [After early discussions to play the Apple fou...
# 48539  [Kevin Vickers, sergeant-at-arms of the House ...
# ...                                                  ...
# 3391   [Nope., I, a male, taught at an all girls high...
# 46992  [A hoax that went viral on the internet has le...
# 9014   [There is a great responsibility to parenting....
# 19858  [(KTVI)- An audio recording that allegedly cap...
# 11897  [ISIS supporters are circulating images of a c...
#
#                                          embeddings_body
# 47361  [tensor(0.0699), tensor(0.4565), tensor(0.6801...
# 21733  [tensor(-0.0544), tensor(0.2273), tensor(0.712...
# 12631  [tensor(-0.0683), tensor(0.3371), tensor(0.664...
# 43533  [tensor(0.0629), tensor(0.3318), tensor(0.6999...
# 48539  [tensor(-0.1887), tensor(0.4966), tensor(0.432...
# ...                                                  ...
# 3391   [tensor(-0.0292), tensor(0.2782), tensor(1.122...
# 46992  [tensor(0.0620), tensor(0.3018), tensor(0.3126...
# 9014   [tensor(-0.0828), tensor(0.2738), tensor(1.438...
# 19858  [tensor(0.1169), tensor(0.2531), tensor(0.1378...
# 11897  [tensor(0.0842), tensor(0.4498), tensor(0.0074...
#
# [12841 rows x 8 columns]

# %%
pkl.dump(total_train_copy, open('/gpt_embeddings/total_train_mean.pkl','wb'))
pkl.dump(total_val_copy, open('/gpt_embeddings/total_val_mean.pkl','wb'))

# %%
total_train['embeddings_head']

# %%
temp = pd.read_csv('/gpt_embeddings/test2.csv')

# %%
temp.head()
# Out:
#                                             Headline  Body ID  \
# 0  Ferguson riots: Pregnant woman loses eye after...     2008
# 1  Apple Stores to install safes to secure gold A...     2008
# 2  Pregnant woman loses eye after police shoot be...     2008
# 3  We just found out the #Ferguson Protester who ...     2008
# 4  Police Chief In Charge of Paris Attacks Commit...     2008
#
#                                       sentences_head  \
# 0  ['Ferguson riots: Pregnant woman loses eye aft...
# 1  ['Apple Stores to install safes to secure gold...
# 2  ['Pregnant woman loses eye after police shoot ...
# 3  ['We just found out the #Ferguson Protester wh...
# 4  ['Police Chief In Charge of Paris Attacks Comm...
#
#                                      embeddings_head  \
# 0  [[ 0.317956    0.59476596 -0.22569571 -0.28339...
# 1  [[-8.70428234e-02  1.49100876e+00 -7.10931659e...
# 2  [[-2.49820314e-02  2.49536976e-01 -1.13435455e...
# 3  [[ 0.54422915  0.79883075 -0.63868016 ...  0.3...
# 4  [[ 4.13983725e-02  2.24963576e-01  5.47654569e...
#
#                                          articleBody  \
# 0  A RESPECTED senior French police officer inves...
# 1  A RESPECTED senior French police officer inves...
# 2  A RESPECTED senior French police officer inves...
# 3  A RESPECTED senior French police officer inves...
# 4  A RESPECTED senior French police officer inves...
#
#                                       sentences_body  \
# 0  ['A RESPECTED senior French police officer inv...
# 1  ['A RESPECTED senior French police officer inv...
# 2  ['A RESPECTED senior French police officer inv...
# 3  ['A RESPECTED senior French police officer inv...
# 4  ['A RESPECTED senior French police officer inv...
#
#                                      embeddings_body  Unnamed: 7  Unnamed: 8  \
# 0  [[-1.15868144e-01  4.64112371e-01 -7.01989383e...          58          35
# 1  [[-1.15868144e-01  4.64112371e-01 -7.01989383e...          35          19
# 2  [[-1.15868144e-01  4.64112371e-01 -7.01989383e...          46          32
# 3  [[-1.15868144e-01  4.64112371e-01 -7.01989383e...          67          56
# 4  [[-1.15868144e-01  4.64112371e-01 -7.01989383e...          40          34
#
#    Unnamed: 9  ...  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0          15  ...            0            0            0            0
# 1           5  ...            0            0            0            0
# 2          18  ...            0            0            0            0
# 3          31  ...            0            0            0            1
# 4          22  ...            0            0            0            0
#
#    Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# 0            0            0            0            0     0.000000
# 1            0            0            0            0     0.000000
# 2            0            0            0            0     0.091268
# 3            0            0            0            0     0.007743
# 4            0            0            0            0     0.130289
#
#    Unnamed: 28
# 0       0.2050
# 1       1.4171
# 2       0.4237
# 3       0.9956
# 4       0.1882
#
# [5 rows x 29 columns]

# %%
fnc_val = pkl.load(open('/gpt_embeddings/fnc_val.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 fnc_val = pkl.load(open('/gpt_embeddings/fnc_val.pkl','rb'))
#
# File c:\Users\Song\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gpt_embeddings/fnc_val.pkl'

# %%
body_train['embeddings'] = body_train['sentences'].apply(get_embedding)

# %%
head_train['embeddings'] = head_train['sentences'].apply(get_embedding)

# %%
pkl.dump(body_train, open('arcbody.pkl','wb'))
pkl.dump(head_train, open('archead.pkl','wb'))

# %%
body_train.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        4  Last week we hinted at what was to come as Ebo...
# 2        5  (NEWSER) – Wonder how long a Quarter Pounder w...
# 3        6  Posting photos of a gun-toting child online, I...
# 4        7  At least 25 suspected Boko Haram insurgents we...
#
#                                            sentences  \
# 0  [A small meteorite crashed into a wooded area ...
# 1  [Last week we hinted at what was to come as Eb...
# 2  [(NEWSER) – Wonder how long a Quarter Pounder ...
# 3  [Posting photos of a gun-toting child online, ...
# 4  [At least 25 suspected Boko Haram insurgents w...
#
#                                           embeddings
# 0  [[0.04417499, 0.2813075, 0.08948864, 0.4299080...
# 1  [[0.3306326, -0.3482146, 0.4529167, 0.09398288...
# 2  [[-0.18273714, 0.75774044, -0.06936457, -0.440...
# 3  [[0.08154284, 0.5142628, 0.0099390745, 0.10628...
# 4  [[-0.16386387, 0.12687834, -0.89488053, -0.150...

# %%
head_train.head()
# Out:
#                                             Headline  Body ID     Stance  \
# 0  Police find mass graves with at least '15 bodi...      712  unrelated
# 1  Hundreds of Palestinians flee floods in Gaza a...      158      agree
# 2  Christian Bale passes on role of Steve Jobs, a...      137  unrelated
# 3  HBO and Apple in Talks for $15/Month Apple TV ...     1034  unrelated
# 4  Spider burrowed through tourist's stomach and ...     1923   disagree
#
#                                            sentences  \
# 0  [Police find mass graves with at least '15 bod...
# 1  [Hundreds of Palestinians flee floods in Gaza ...
# 2  [Christian Bale passes on role of Steve Jobs, ...
# 3  [HBO and Apple in Talks for $15/Month Apple TV...
# 4  [Spider burrowed through tourist's stomach and...
#
#                                           embeddings
# 0  [[0.11373772, 0.32614568, -0.36455876, 0.34818...
# 1  [[0.0035811067, 0.66388166, -0.3805887, 0.0164...
# 2  [[-0.17844312, 0.40808, 0.90333754, -0.0021085...
# 3  [[-0.46256074, 0.61089754, 0.06796886, -0.2900...
# 4  [[-0.43532988, 0.84769005, -0.26739606, -0.038...

# %%
import torch.nn.functional as F

# %%
a = sent[0]

# %%
s = sent[1]

# %%
s = "I'm a happy student studying in a university."

# %%
a_ = torch.tensor(model.encode(a))

# %%
s_ = torch.tensor(model.encode(s))

# %%
F.cosine_similarity(a_.unsqueeze(0),s_.unsqueeze(0))
# Out:
# tensor([0.6480])

# %%
body_train['embeddings'] = body_train['sentences'].apply(get_embedding)

# %%
body_train.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        4  Last week we hinted at what was to come as Ebo...
# 2        5  (NEWSER) – Wonder how long a Quarter Pounder w...
# 3        6  Posting photos of a gun-toting child online, I...
# 4        7  At least 25 suspected Boko Haram insurgents we...
#
#                                            sentences  \
# 0  [A small meteorite crashed into a wooded area ...
# 1  [Last week we hinted at what was to come as Eb...
# 2  [(NEWSER) – Wonder how long a Quarter Pounder ...
# 3  [Posting photos of a gun-toting child online, ...
# 4  [At least 25 suspected Boko Haram insurgents w...
#
#                                           embeddings
# 0  [[0.04417499, 0.2813075, 0.08948864, 0.4299080...
# 1  [[0.3306326, -0.3482146, 0.4529167, 0.09398288...
# 2  [[-0.18273714, 0.75774044, -0.06936457, -0.440...
# 3  [[0.08154284, 0.5142628, 0.0099390745, 0.10628...
# 4  [[-0.16386387, 0.12687834, -0.89488053, -0.150...

# %%
body_test['embeddings'] = body_test['sentences'].apply(get_embedding)

# %%
body_test.head()
# Out:
#    Body ID                                        articleBody  \
# 0        1  Al-Sisi has denied Israeli reports stating tha...
# 1        2  A bereaved Afghan mother took revenge on the T...
# 2        3  CNBC is reporting Tesla has chosen Nevada as t...
# 3       12  A 4-inch version of the iPhone 6 is said to be...
# 4       19  GR editor’s Note\r\n\r\nThere are no reports i...
#
#                                            sentences  \
# 0  [Al-Sisi has denied Israeli reports stating th...
# 1  [A bereaved Afghan mother took revenge on the ...
# 2  [CNBC is reporting Tesla has chosen Nevada as ...
# 3  [A 4-inch version of the iPhone 6 is said to b...
# 4  [GR editor’s Note\r\n\r\nThere are no reports ...
#
#                                           embeddings
# 0  [[0.31010464, 0.20827565, 0.23084044, -0.47201...
# 1  [[0.003925855, 0.06509211, -0.0727313, 0.12800...
# 2  [[0.52243996, 1.0500185, 0.61583394, 0.4663079...
# 3  [[-0.22461553, 0.310677, 1.6420063, -0.1729198...
# 4  [[0.7256343, 0.71487296, 0.795531, -0.22592303...

# %%
stance_train.head()
# Out:
#                                             Headline  Body ID     Stance  \
# 0  Police find mass graves with at least '15 bodi...      712  unrelated
# 1  Hundreds of Palestinians flee floods in Gaza a...      158      agree
# 2  Christian Bale passes on role of Steve Jobs, a...      137  unrelated
# 3  HBO and Apple in Talks for $15/Month Apple TV ...     1034  unrelated
# 4  Spider burrowed through tourist's stomach and ...     1923   disagree
#
#                                            sentences
# 0  [Police find mass graves with at least '15 bod...
# 1  [Hundreds of Palestinians flee floods in Gaza ...
# 2  [Christian Bale passes on role of Steve Jobs, ...
# 3  [HBO and Apple in Talks for $15/Month Apple TV...
# 4  [Spider burrowed through tourist's stomach and...

# %%
stance_train['embeddings'] = stance_train['sentences'].apply(get_embedding)

# %%
stance_train.head()
# Out:
#                                             Headline  Body ID     Stance  \
# 0  Police find mass graves with at least '15 bodi...      712  unrelated
# 1  Hundreds of Palestinians flee floods in Gaza a...      158      agree
# 2  Christian Bale passes on role of Steve Jobs, a...      137  unrelated
# 3  HBO and Apple in Talks for $15/Month Apple TV ...     1034  unrelated
# 4  Spider burrowed through tourist's stomach and ...     1923   disagree
#
#                                            sentences  \
# 0  [Police find mass graves with at least '15 bod...
# 1  [Hundreds of Palestinians flee floods in Gaza ...
# 2  [Christian Bale passes on role of Steve Jobs, ...
# 3  [HBO and Apple in Talks for $15/Month Apple TV...
# 4  [Spider burrowed through tourist's stomach and...
#
#                                           embeddings
# 0  [[0.11373772, 0.32614568, -0.36455876, 0.34818...
# 1  [[0.0035811067, 0.66388166, -0.3805887, 0.0164...
# 2  [[-0.17844312, 0.40808, 0.90333754, -0.0021085...
# 3  [[-0.46256074, 0.61089754, 0.06796886, -0.2900...
# 4  [[-0.43532988, 0.84769005, -0.26739606, -0.038...

# %%
stance_test['embeddings'] = stance_test['sentences'].apply(get_embedding)

# %%
stance_test.head()
# Out:
#                                             Headline  Body ID  \
# 0  Ferguson riots: Pregnant woman loses eye after...     2008
# 1  Crazy Conservatives Are Sure a Gitmo Detainee ...     1550
# 2  A Russian Guy Says His Justin Bieber Ringtone ...        2
# 3  Zombie Cat: Buried Kitty Believed Dead, Meows ...     1793
# 4  Argentina's President Adopts Boy to End Werewo...       37
#
#                                            sentences  \
# 0  [Ferguson riots: Pregnant woman loses eye afte...
# 1  [Crazy Conservatives Are Sure a Gitmo Detainee...
# 2  [A Russian Guy Says His Justin Bieber Ringtone...
# 3  [Zombie Cat: Buried Kitty Believed Dead, Meows...
# 4  [Argentina's President Adopts Boy to End Werew...
#
#                                           embeddings
# 0  [[0.317956, 0.59476596, -0.22569571, -0.283397...
# 1  [[-0.14443071, 0.41816604, -0.11379044, 0.2560...
# 2  [[-0.23880617, 0.9361699, -0.14230421, -0.1047...
# 3  [[0.031023404, 1.1899894, 0.22445874, -0.47767...
# 4  [[-0.18823671, 0.3684826, 0.056638524, 0.52585...

# %%
pkl.dump(body_test, open('/gpt_embeddings/body_test.pkl', 'wb+'))
pkl.dump(body_train, open('/gpt_embeddings/body_train.pkl', 'wb+'))

# %%
pkl.dump(stance_train, open('/gpt_embeddings/stance_train.pkl', 'wb+'))
pkl.dump(stance_test, open('/gpt_embeddings/stance_test.pkl', 'wb+'))
