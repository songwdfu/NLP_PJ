# %%
import pickle as pkl
from matplotlib import pyplot as plt

# %%
history = pkl.load(open('total_ext_history_ep50.pkl','rb'))

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.show()
